# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import pygenesys as pg
from plotter import *
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,12)

# %%
from mycolorpy import colorlist as mcp
import numpy as np
N_regions = 20
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}

# %% [markdown]
# ### 4 Seasons N regions

# %%
N_seasons = 4

# %%
N_regions = 2
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    69.217395
# dtype: float64

# %%
N_regions = 5
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    86.907103
# dtype: float64

# %%
N_regions = 10
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    87.453065
# dtype: float64

# %%
N_regions = 20
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
ax = (cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
ax.legend(loc=(1.05,0.1))
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    87.544945
# dtype: float64

# %% [markdown]
# ### 12 Seasons N Regions

# %%
N_seasons = 12

# %%
N_regions = 2
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    60.819806
# dtype: float64

# %%
N_regions = 5
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    68.068685
# dtype: float64

# %%
N_regions = 10
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    89.717611
# dtype: float64

# %%
N_regions = 20
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
ax = (cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
ax.legend(loc=(1.05,0.1))
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    81.115261
# dtype: float64

# %% [markdown]
# ### 52 Seasons N Regions

# %%
N_seasons = 52

# %%
N_regions = 2
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    45.75678
# dtype: float64

# %%
N_regions = 5
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    46.767649
# dtype: float64

# %%
N_regions = 10
color1=mcp.gen_color(cmap="Purples_r",n=N_regions)
color2=mcp.gen_color(cmap="autumn_r",n=N_regions)
sol_colors = {f"SOLAR_FARM_{n+1}":color2[n] for n in range(N_regions)}
wind_colors = {f"WIND_FARM_{n+1}":color1[n] for n in range(N_regions)}
all_colors = {**elc_colors, **sol_colors, **wind_colors}


sim_path = f"/home/sdotson/research/illinois_gis/temoa_dir/least_cost/illinois_LC_{N_regions}_{N_seasons}.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_2_52 = get_annual_capacity(conn, 'IL', 'ELC' )
ax = (cap_df_2_52/1000).plot(kind='bar', stacked=True, color=all_colors)
ax.legend(loc=(1.05,0.1))
plt.title(f'Capacity Plot for Scenario: Least Cost \n {N_regions} Regions, {N_seasons} Seasons')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
print(cap_df_2_52[cap_df_2_52.index==2050].sum(axis=1)/1000)
# Out:
# year
# 2050    56.383594
# dtype: float64
