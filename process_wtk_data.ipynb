# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob 
import os

# %%
path = 'nrel_wtk_data/*.csv'
files = glob.glob(path)
files.sort()
files
# Out:
# ['nrel_wtk_data/ADAMS_39.988_-91.188_wind_2012.csv',
#  'nrel_wtk_data/ALEXANDER_37.191_-89.338_wind_2012.csv',
#  'nrel_wtk_data/BOND_38.887_-89.436_wind_2012.csv',
#  'nrel_wtk_data/BOONE_42.323_-88.823_wind_2012.csv',
#  'nrel_wtk_data/BROWN_39.962_-90.75_wind_2012.csv',
#  'nrel_wtk_data/BUREAU_41.404_-89.529_wind_2012.csv',
#  'nrel_wtk_data/CALHOUN_39.169_-90.668_wind_2012.csv',
#  'nrel_wtk_data/CARROLL_42.069_-89.934_wind_2012.csv',
#  'nrel_wtk_data/CASS_39.974_-90.247_wind_2012.csv',
#  'nrel_wtk_data/CHAMPAIGN_40.14_-88.199_wind_2012.csv',
#  'nrel_wtk_data/CHRISTIAN_39.546_-89.277_wind_2012.csv',
#  'nrel_wtk_data/CLARK_39.334_-87.788_wind_2012.csv',
#  'nrel_wtk_data/CLAY_38.754_-88.49_wind_2012.csv',
#  'nrel_wtk_data/CLINTON_38.606_-89.423_wind_2012.csv',
#  'nrel_wtk_data/COLES_39.52_-88.222_wind_2012.csv',
#  'nrel_wtk_data/COOK_41.84_-87.817_wind_2012.csv',
#  'nrel_wtk_data/CRAWFORD_39.003_-87.76_wind_2012.csv',
#  'nrel_wtk_data/CUMBERLAND_39.273_-88.24_wind_2012.csv',
#  'nrel_wtk_data/DEKALB_41.894_-88.77_wind_2012.csv',
#  'nrel_wtk_data/DEWITT_40.175_-88.904_wind_2012.csv',
#  'nrel_wtk_data/DOUGLAS_39.769_-88.217_wind_2012.csv',
#  'nrel_wtk_data/DUPAGE_41.852_-88.086_wind_2012.csv',
#  'nrel_wtk_data/EDGAR_39.679_-87.746_wind_2012.csv',
#  'nrel_wtk_data/EDWARDS_38.417_-88.053_wind_2012.csv',
#  'nrel_wtk_data/EFFINGHAM_39.06_-88.59_wind_2012.csv',
#  'nrel_wtk_data/FAYETTE_39.0_-89.024_wind_2012.csv',
#  'nrel_wtk_data/FORD_40.597_-88.223_wind_2012.csv',
#  'nrel_wtk_data/FRANKLIN_37.992_-88.924_wind_2012.csv',
#  'nrel_wtk_data/FULTON_40.473_-90.207_wind_2012.csv',
#  'nrel_wtk_data/GALLATIN_37.763_-88.231_wind_2012.csv',
#  'nrel_wtk_data/GREENE_39.356_-90.39_wind_2012.csv',
#  'nrel_wtk_data/GRUNDY_41.285_-88.418_wind_2012.csv',
#  'nrel_wtk_data/HAMILTON_38.082_-88.539_wind_2012.csv',
#  'nrel_wtk_data/HANCOCK_40.404_-91.165_wind_2012.csv',
#  'nrel_wtk_data/HARDIN_37.518_-88.267_wind_2012.csv',
#  'nrel_wtk_data/HENDERSON_40.818_-90.925_wind_2012.csv',
#  'nrel_wtk_data/HENRY_41.353_-90.132_wind_2012.csv',
#  'nrel_wtk_data/IROQUOIS_40.747_-87.824_wind_2012.csv',
#  'nrel_wtk_data/JACKSON_37.785_-89.383_wind_2012.csv',
#  'nrel_wtk_data/JASPER_39.01_-88.154_wind_2012.csv',
#  'nrel_wtk_data/JEFFERSON_38.301_-88.924_wind_2012.csv',
#  'nrel_wtk_data/JERSEY_39.086_-90.356_wind_2012.csv',
#  'nrel_wtk_data/JO DAVIESS_42.366_-90.212_wind_2012.csv',
#  'nrel_wtk_data/JOHNSON_37.46_-88.881_wind_2012.csv',
#  'nrel_wtk_data/KANE_41.939_-88.429_wind_2012.csv',
#  'nrel_wtk_data/KANKAKEE_41.138_-87.862_wind_2012.csv',
#  'nrel_wtk_data/KENDALL_41.591_-88.429_wind_2012.csv',
#  'nrel_wtk_data/KNOX_40.932_-90.213_wind_2012.csv',
#  'nrel_wtk_data/LAKE_42.323_-88.004_wind_2012.csv',
#  'nrel_wtk_data/LASALLE_41.344_-88.886_wind_2012.csv',
#  'nrel_wtk_data/LAWRENCE_38.72_-87.727_wind_2012.csv',
#  'nrel_wtk_data/LEE_41.746_-89.3_wind_2012.csv',
#  'nrel_wtk_data/LIVINGSTON_40.892_-88.558_wind_2012.csv',
#  'nrel_wtk_data/LOGAN_40.125_-89.367_wind_2012.csv',
#  'nrel_wtk_data/MACON_39.86_-88.962_wind_2012.csv',
#  'nrel_wtk_data/MACOUPIN_39.261_-89.924_wind_2012.csv',
#  'nrel_wtk_data/MADISON_38.83_-89.905_wind_2012.csv',
#  'nrel_wtk_data/MARION_38.65_-88.919_wind_2012.csv',
#  'nrel_wtk_data/MARSHALL_41.033_-89.345_wind_2012.csv',
#  'nrel_wtk_data/MASON_40.24_-89.917_wind_2012.csv',
#  'nrel_wtk_data/MASSAC_37.219_-88.708_wind_2012.csv',
#  'nrel_wtk_data/MCDONOUGH_40.456_-90.678_wind_2012.csv',
#  'nrel_wtk_data/MCHENRY_42.324_-88.452_wind_2012.csv',
#  'nrel_wtk_data/MCLEAN_40.491_-88.847_wind_2012.csv',
#  'nrel_wtk_data/MENARD_40.027_-89.802_wind_2012.csv',
#  'nrel_wtk_data/MERCER_41.206_-90.742_wind_2012.csv',
#  'nrel_wtk_data/MONROE_38.278_-90.177_wind_2012.csv',
#  'nrel_wtk_data/MONTGOMERY_39.231_-89.479_wind_2012.csv',
#  'nrel_wtk_data/MORGAN_39.716_-90.201_wind_2012.csv',
#  'nrel_wtk_data/MOULTRIE_39.642_-88.619_wind_2012.csv',
#  'nrel_wtk_data/OGLE_42.043_-89.321_wind_2012.csv',
#  'nrel_wtk_data/PEORIA_40.788_-89.76_wind_2012.csv',
#  'nrel_wtk_data/PERRY_38.084_-89.367_wind_2012.csv',
#  'nrel_wtk_data/PIATT_40.01_-88.591_wind_2012.csv',
#  'nrel_wtk_data/PIKE_39.623_-90.886_wind_2012.csv',
#  'nrel_wtk_data/POPE_37.413_-88.562_wind_2012.csv',
#  'nrel_wtk_data/PULASKI_37.223_-89.126_wind_2012.csv',
#  'nrel_wtk_data/PUTNAM_41.204_-89.286_wind_2012.csv',
#  'nrel_wtk_data/RANDOLPH_38.052_-89.824_wind_2012.csv',
#  'nrel_wtk_data/RICHLAND_38.712_-88.085_wind_2012.csv',
#  'nrel_wtk_data/ROCK ISLAND_41.467_-90.567_wind_2012.csv',
#  'nrel_wtk_data/SALINE_37.753_-88.541_wind_2012.csv',
#  'nrel_wtk_data/SANGAMON_39.758_-89.659_wind_2012.csv',
#  'nrel_wtk_data/SCHUYLER_40.158_-90.615_wind_2012.csv',
#  'nrel_wtk_data/SCOTT_39.644_-90.475_wind_2012.csv',
#  'nrel_wtk_data/SHELBY_39.391_-88.806_wind_2012.csv',
#  'nrel_wtk_data/ST. CLAIR_38.47_-89.928_wind_2012.csv',
#  'nrel_wtk_data/STARK_41.093_-89.798_wind_2012.csv',
#  'nrel_wtk_data/STEPHENSON_42.352_-89.662_wind_2012.csv',
#  'nrel_wtk_data/TAZEWELL_40.508_-89.513_wind_2012.csv',
#  'nrel_wtk_data/UNION_37.471_-89.255_wind_2012.csv',
#  'nrel_wtk_data/VERMILION_40.183_-87.733_wind_2012.csv',
#  'nrel_wtk_data/WABASH_38.446_-87.844_wind_2012.csv',
#  'nrel_wtk_data/WARREN_40.849_-90.615_wind_2012.csv',
#  'nrel_wtk_data/WASHINGTON_38.352_-89.41_wind_2012.csv',
#  'nrel_wtk_data/WAYNE_38.43_-88.426_wind_2012.csv',
#  'nrel_wtk_data/WHITESIDE_41.756_-89.914_wind_2012.csv',
#  'nrel_wtk_data/WHITE_38.087_-88.18_wind_2012.csv',
#  'nrel_wtk_data/WILLIAMSON_37.73_-88.93_wind_2012.csv',
#  'nrel_wtk_data/WILL_41.445_-87.979_wind_2012.csv',
#  'nrel_wtk_data/WINNEBAGO_42.336_-89.161_wind_2012.csv',
#  'nrel_wtk_data/WOODFORD_40.788_-89.211_wind_2012.csv']

# %%
u_out = 25.0
u_in = 3.5
u_ideal = 12
Pmax=1.5

d = 77
eta = 0.35

P_wind = lambda u, rho, eta: 0.5*eta*rho*(u**3)*(np.pi*d**2)/4

# %%
for file in files:
    fname = file.split('/')[1].strip('.csv')
    print(fname)
    df = pd.read_csv(file,  
                     usecols=['Year','Month', 'Day', 'Hour', 'Minute', 
                              'wind speed at 80m (m/s)',
                              ],)
    cols=['Year','Month', 'Day', 'Hour', 'Minute']
    df['time'] = pd.to_datetime(df[cols])
    df.drop(columns=cols, inplace=True)
    df.set_index('time', inplace=True)    
    
    df = df.resample('H').mean()
    df['density'] = 1.225 # kg/m^3, typical air density at sea level
    df['kw_wind'] = P_wind(df['wind speed at 80m (m/s)'], df['density'], eta)/1e6
    zero = (df['wind speed at 80m (m/s)'] < u_in) | (df['wind speed at 80m (m/s)'] >= u_out)
    peak = (df['wind speed at 80m (m/s)'] > u_ideal) & (df['wind speed at 80m (m/s)'] <= u_out)
    df.kw_wind.mask(zero, 0, inplace=True)
    df.kw_wind.mask(peak, Pmax, inplace=True)
    peak2 = (df.kw_wind > Pmax)
    df.kw_wind.mask(peak2, Pmax, inplace=True)
    df[['kw_wind']].to_csv(f'wtk_transformed/{fname}_transformed.csv')
# Out:
# ADAMS_39.988_-91.188_wind_2012
# ALEXANDER_37.191_-89.338_wind_2012
# BOND_38.887_-89.436_wind_2012
# BOONE_42.323_-88.823_wind_2012
# BROWN_39.962_-90.75_wind_2012
# BUREAU_41.404_-89.529_wind_2012
# CALHOUN_39.169_-90.668_wind_2012
# CARROLL_42.069_-89.934_wind_2012
# CASS_39.974_-90.247_wind_2012
# CHAMPAIGN_40.14_-88.199_wind_2012
# CHRISTIAN_39.546_-89.277_wind_2012
# CLARK_39.334_-87.788_wind_2012
# CLAY_38.754_-88.49_wind_2012
# CLINTON_38.606_-89.423_wind_2012
# COLES_39.52_-88.222_wind_2012
# COOK_41.84_-87.817_wind_2012
# CRAWFORD_39.003_-87.76_wind_2012
# CUMBERLAND_39.273_-88.24_wind_2012
# DEKALB_41.894_-88.77_wind_2012
# DEWITT_40.175_-88.904_wind_2012
# DOUGLAS_39.769_-88.217_wind_2012
# DUPAGE_41.852_-88.086_wind_2012
# EDGAR_39.679_-87.746_wind_2012
# EDWARDS_38.417_-88.053_wind_2012
# EFFINGHAM_39.06_-88.59_wind_2012
